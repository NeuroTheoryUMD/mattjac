# %%
import experiment as exp
# Out:
# Invoking __init__.py for NDNT.utils

# %%
e = exp.load('exp_TCNIM', 'experiments')

# %%
e.trials_where(name='TCNIM_NF4_expt04')[0].model.draw_network()

# %%
e.trials
# Out:
#    num_filters                         expt  \
# 0            4                       expt04
# 0            4                expt04+expt05
# 0            4         expt04+expt05+expt06
# 0            4  expt04+expt05+expt06+expt07
# 0            6                       expt04
# 0            6                expt04+expt05
# 0            6         expt04+expt05+expt06
# 0            6  expt04+expt05+expt06+expt07
# 0            8                       expt04
# 0            8                expt04+expt05
# 0            8         expt04+expt05+expt06
# 0            8  expt04+expt05+expt06+expt07
#
#                                     name  \
# 0                       TCNIM_NF4_expt04
# 0                TCNIM_NF4_expt04+expt05
# 0         TCNIM_NF4_expt04+expt05+expt06
# 0  TCNIM_NF4_expt04+expt05+expt06+expt07
# 0                       TCNIM_NF6_expt04
# 0                TCNIM_NF6_expt04+expt05
# 0         TCNIM_NF6_expt04+expt05+expt06
# 0  TCNIM_NF6_expt04+expt05+expt06+expt07
# 0                       TCNIM_NF8_expt04
# 0                TCNIM_NF8_expt04+expt05
# 0         TCNIM_NF8_expt04+expt05+expt06
# 0  TCNIM_NF8_expt04+expt05+expt06+expt07
#
#                                          trial
# 0  <experiment.Trial object at 0x7f8bb987d190>
# 0  <experiment.Trial object at 0x7f8bb9888130>
# 0  <experiment.Trial object at 0x7f8bb98dd8e0>
# 0  <experiment.Trial object at 0x7f8c981f06d0>
# 0  <experiment.Trial object at 0x7f8bb995a730>
# 0  <experiment.Trial object at 0x7f8bb9796460>
# 0  <experiment.Trial object at 0x7f8bb98ca100>
# 0  <experiment.Trial object at 0x7f8bb98b1190>
# 0  <experiment.Trial object at 0x7f8bb98cad90>
# 0  <experiment.Trial object at 0x7f8bb98b19d0>
# 0  <experiment.Trial object at 0x7f8bb98d2fa0>
# 0  <experiment.Trial object at 0x7f8bb97c91f0>

# %%
e.plot_LLs(trials=e.trials_where(num_filters=8))

# %%
e.plot_losses(trials=e.trials_where(num_filters=8), figsize=(25,5))
