# %%
import sys
# not best practice, but makes it easier to import from subdirectory
sys.path.insert(0, './lib')
sys.path.insert(0, './archive')

import experiment as exp
import plot

# %load_ext autoreload
# %autoreload 2
# Out:
# Invoking __init__.py for NDNT.utils

# %%
e = exp.load('exp_multiple_models', experiment_location='experiments', datadir='./Mdata')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 e = exp.load('exp_multiple_models', experiment_location='experiments', datadir='./Mdata')
#
# File ~/projects/mattjac/v1/./lib/experiment.py:76, in load(expname, experiment_location, datadir, lazy)
#      74 def load(expname, experiment_location, datadir=None, lazy=True): # load experiment
#      75     experiment_folder = os.path.join(experiment_location, expname)
# ---> 76     with open(os.path.join(experiment_folder, 'exp_params.pickle'), 'rb') as f:
#      77         exp_params = pickle.load(f)
#      79     experiment = Experiment(name=expname,
#      80                             description=exp_params['description'],
#      81                             generate_trial=None,
#      82                             experiment_location=experiment_location,
#      83                             datadir=datadir,
#      84                             overwrite=Overwrite.overwrite)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'experiments/exp_multiple_models/exp_params.pickle'

# %%
e.trials
# Out:
#    num_filters                         expt  kernel_height  \
# 0           16                       expt04              5
# 0           16                expt04+expt05              5
# 0           16                       expt04              5
# 0           16                expt04+expt05              5
# 0           16         expt04+expt05+expt06              5
# 0           16  expt04+expt05+expt06+expt07              5
# 0           16         expt04+expt05+expt06              5
# 0           16  expt04+expt05+expt06+expt07              5
# 0           16                       expt04              5
# 0           16                expt04+expt05              5
# 0           16         expt04+expt05+expt06              5
# 0           16  expt04+expt05+expt06+expt07              5
# 0           16                       expt04              5
# 0           16                expt04+expt05              5
# 0           16         expt04+expt05+expt06              5
# 0           16  expt04+expt05+expt06+expt07              5
# 0           16         expt04+expt05+expt06              5
# 0           16  expt04+expt05+expt06+expt07              5
# 0           16                       expt04              5
# 0           16                expt04+expt05              5
# 0           16         expt04+expt05+expt06              5
# 0           16  expt04+expt05+expt06+expt07              5
# 0           16                       expt04              5
# 0           16                expt04+expt05              5
# 0           16                       expt04              5
# 0           16                expt04+expt05              5
# 0           16         expt04+expt05+expt06              5
# 0           16  expt04+expt05+expt06+expt07              5
# 0           16                       expt04              5
# 0           16                expt04+expt05              5
#
#                                             reg_vals        modelstr  \
# 0  {'d2xt': 0.01, 'l1': 0.0001, 'center': 0.01, '...            cnim
# 0  {'d2xt': 0.01, 'l1': 0.0001, 'center': 0.01, '...            cnim
# 0  {'d2xt': 0.05, 'l1': 0.0001, 'center': 0.01, '...            cnim
# 0  {'d2xt': 0.05, 'l1': 0.0001, 'center': 0.01, '...            cnim
# 0  {'d2xt': 0.05, 'l1': 0.0001, 'center': 0.01, '...            cnim
# 0  {'d2xt': 0.05, 'l1': 0.0001, 'center': 0.01, '...            cnim
# 0  {'d2xt': 0.01, 'l1': 0.0001, 'center': 0.01, '...            cnim
# 0  {'d2xt': 0.01, 'l1': 0.0001, 'center': 0.01, '...            cnim
# 0  {'d2xt': 0.05, 'l1': 0.0001, 'center': 0.01, '...   cnim_scaffold
# 0  {'d2xt': 0.05, 'l1': 0.0001, 'center': 0.01, '...   cnim_scaffold
# 0  {'d2xt': 0.05, 'l1': 0.0001, 'center': 0.01, '...   cnim_scaffold
# 0  {'d2xt': 0.05, 'l1': 0.0001, 'center': 0.01, '...   cnim_scaffold
# 0  {'d2xt': 0.01, 'l1': 0.0001, 'center': 0.01, '...   cnim_scaffold
# 0  {'d2xt': 0.01, 'l1': 0.0001, 'center': 0.01, '...   cnim_scaffold
# 0  {'d2xt': 0.01, 'l1': 0.0001, 'center': 0.01, '...   cnim_scaffold
# 0  {'d2xt': 0.01, 'l1': 0.0001, 'center': 0.01, '...   cnim_scaffold
# 0  {'d2xt': 0.01, 'l1': 0.0001, 'center': 0.01, '...           tcnim
# 0  {'d2xt': 0.01, 'l1': 0.0001, 'center': 0.01, '...           tcnim
# 0  {'d2xt': 0.05, 'l1': 0.0001, 'center': 0.01, '...           tcnim
# 0  {'d2xt': 0.05, 'l1': 0.0001, 'center': 0.01, '...           tcnim
# 0  {'d2xt': 0.05, 'l1': 0.0001, 'center': 0.01, '...           tcnim
# 0  {'d2xt': 0.05, 'l1': 0.0001, 'center': 0.01, '...           tcnim
# 0  {'d2xt': 0.01, 'l1': 0.0001, 'center': 0.01, '...           tcnim
# 0  {'d2xt': 0.01, 'l1': 0.0001, 'center': 0.01, '...           tcnim
# 0  {'d2xt': 0.01, 'l1': 0.0001, 'center': 0.01, '...  tcnim_scaffold
# 0  {'d2xt': 0.01, 'l1': 0.0001, 'center': 0.01, '...  tcnim_scaffold
# 0  {'d2xt': 0.01, 'l1': 0.0001, 'center': 0.01, '...  tcnim_scaffold
# 0  {'d2xt': 0.01, 'l1': 0.0001, 'center': 0.01, '...  tcnim_scaffold
# 0  {'d2xt': 0.05, 'l1': 0.0001, 'center': 0.01, '...  tcnim_scaffold
# 0  {'d2xt': 0.05, 'l1': 0.0001, 'center': 0.01, '...  tcnim_scaffold
#
#                name                                        trial  mean_LLs
# 0             cnim0  <experiment.Trial object at 0x7f45599012e0>  0.387204
# 0             cnim1  <experiment.Trial object at 0x7f4559a30100>  0.179294
# 0            cnim16  <experiment.Trial object at 0x7f4559901130>  0.375183
# 0            cnim17  <experiment.Trial object at 0x7f4559cf39d0>  0.089433
# 0            cnim18  <experiment.Trial object at 0x7f45598b0910>  0.045480
# 0            cnim19  <experiment.Trial object at 0x7f4559d71e50> -0.024057
# 0             cnim2  <experiment.Trial object at 0x7f4559a24550>  0.068619
# 0             cnim3  <experiment.Trial object at 0x7f4559a30e80>  0.045936
# 0   cnim_scaffold20  <experiment.Trial object at 0x7f455985f4c0>  0.392278
# 0   cnim_scaffold21  <experiment.Trial object at 0x7f4559d1cc40> -0.007341
# 0   cnim_scaffold22  <experiment.Trial object at 0x7f4559d02550>  0.065761
# 0   cnim_scaffold23  <experiment.Trial object at 0x7f4559a0dc10> -0.017463
# 0    cnim_scaffold4  <experiment.Trial object at 0x7f4559d18940>  0.402252
# 0    cnim_scaffold5  <experiment.Trial object at 0x7f4559d653a0>  0.007898
# 0    cnim_scaffold6  <experiment.Trial object at 0x7f4559d60280>  0.105757
# 0    cnim_scaffold7  <experiment.Trial object at 0x7f4559d69070>  0.052673
# 0           tcnim10  <experiment.Trial object at 0x7f4559d123a0>  0.024952
# 0           tcnim11  <experiment.Trial object at 0x7f4559d69340> -1.575776
# 0           tcnim24  <experiment.Trial object at 0x7f4559d1c340>  0.403030
# 0           tcnim25  <experiment.Trial object at 0x7f455985feb0>  0.012982
# 0           tcnim26  <experiment.Trial object at 0x7f455996b3a0>  0.036177
# 0           tcnim27  <experiment.Trial object at 0x7f4559d0c370> -1.129609
# 0            tcnim8  <experiment.Trial object at 0x7f455a083fa0>  0.432988
# 0            tcnim9  <experiment.Trial object at 0x7f455c51e1c0>  0.067032
# 0  tcnim_scaffold12  <experiment.Trial object at 0x7f4559d71d90>  0.394379
# 0  tcnim_scaffold13  <experiment.Trial object at 0x7f455a250f40> -0.020907
# 0  tcnim_scaffold14  <experiment.Trial object at 0x7f4559d66340>  0.074000
# 0  tcnim_scaffold15  <experiment.Trial object at 0x7f455996b2e0>  0.027073
# 0  tcnim_scaffold28  <experiment.Trial object at 0x7f4559d66c70>  0.356507
# 0  tcnim_scaffold29  <experiment.Trial object at 0x7f4559d83af0>  0.035486

# %%
# plot predictions
model = e.trials_where(name='cnim0')[0].model
plot.plot_network_weights(model.networks[0], wspace=0.1, hspace=0.5, max_cols=4, figsize=(10,10))
# Out:
# (21, 10, 16) --> (16, 10, 21)
# (16, 36, 11) --> (11, 36, 16)

# %%
import torch
import numpy as np

trial = e.trials_where(name='cnim0')[0]
model = trial.model
inps = trial.dataset.stim[:100]

# %%
# get all the outputs
# TODO: use the NDN, not the model object directly
prev_output = inps
all_outputs = []
for n in range(len(model.NDN.networks)):
    for l in range(len(model.NDN.networks[n].layers)):
        z = model.NDN.networks[n].layers[l](prev_output)
        # TODO: not entirely sure if I need to detach twice
        z_cpu = torch.tensor(np.array([z_i.detach().numpy() for z_i in z]))
        all_outputs.append(z_cpu.numpy())
        print(prev_output.shape, '-->', z_cpu.shape)
        prev_output = z_cpu


layers = []
for n in range(len(model.NDN.networks)):
    for l in range(len(model.NDN.networks[n].layers)):
        layer = model.NDN.networks[n].layers[l].get_weights()
        layers.append(layer)
# Out:
# torch.Size([100, 360]) --> torch.Size([100, 576])
# torch.Size([100, 576]) --> torch.Size([100, 11])

# %%
# TODO: get this working again with the new interface
# TODO: add in plotting robs functionality
figs = plot.render_network(inp=inps[0], stim_dims=trial.dataset.stim_dims, outputs=all_outputs, layers=layers)

# %%
import predict

res = predict.predict(model, dataset=trial.dataset)

# %%
res.pred[:,0]
# Out:
# array([0.02886181, 0.04395458, 0.05666052, ..., 0.67438394, 0.26300707,
#        0.03951599], dtype=float32)

# %%
trial.dataset.stim[0].shape, trial.dataset.robs[0].shape, trial.dataset.stim_dims
# Out:
# (torch.Size([360]), torch.Size([11]), [1, 36, 1, 10])

# %%
plot.simulate(model=model,
              dataset=trial.dataset,
              timestep=10)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 plot.simulate(model=model,
#       2               inps=trial.dataset.stim[0],
#       3               robs=trial.dataset.robs[0],
#       4               stim_dims=trial.dataset.stim_dims)
#
# File ~/projects/mattjac/v1/./lib/plot.py:197, in simulate(model, inps, robs, stim_dims)
#     194         layers.append(layer)
#     196 import predict
# --> 197 res = predict.predict(model, inps=inps, robs=robs)
#     198 return render_network(inps, stim_dims, res.outputs, layers)
#
# File ~/projects/mattjac/v1/./lib/predict.py:73, in predict(model, inps, robs, dataset, verbose)
#      67 # outputs is layers x num_inputs x dims
#      68 # but we want, num_inputs x layers x dims
#      69 # get the outputs for the current input inpi for each layer
#      70 # expand each output dims to be 1xdim as well
#      71 for i in range(num_inps): # for each input
#      72     # add model predictions for this layer
# ---> 73     all_outputs[i][model.networks[ni].name].append(np.expand_dims(z_cpu[i], 0))
#      74 if verbose:
#      75     print(prev_output.shape, '-->', z_torch.shape)
#
# IndexError: list index out of range
