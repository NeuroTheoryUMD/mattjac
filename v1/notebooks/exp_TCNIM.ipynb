# %%
import experiment as exp
import plot

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
e = exp.load('exp_TCNIM_inh', 'experiments')
e.trials
# Out:
#    num_filters  num_lag  num_inh                         expt      name  \
# 0            8        3        0                       expt04   TCNIM_0
# 0           12        5        0                       expt04   TCNIM_1
# 0           12        5        6                expt04+expt05  TCNIM_10
# 0           16        7        8                expt04+expt05  TCNIM_11
# 0            8        3        0         expt04+expt05+expt06  TCNIM_12
# 0           12        5        0         expt04+expt05+expt06  TCNIM_13
# 0           16        7        0         expt04+expt05+expt06  TCNIM_14
# 0            8        3        4         expt04+expt05+expt06  TCNIM_15
# 0           12        5        6         expt04+expt05+expt06  TCNIM_16
# 0           16        7        8         expt04+expt05+expt06  TCNIM_17
# 0            8        3        0  expt04+expt05+expt06+expt07  TCNIM_18
# 0           12        5        0  expt04+expt05+expt06+expt07  TCNIM_19
# ...

# %%
e.plot_LLs(trials=e.trials_where(num_filters=16))

# %%
e.plot_losses(trials=e.trials_where(num_filters=8), figsize=(25,5))

# %%
plot.graymode()
model = e.trials_where(name='TCNIM_0')[0].model
plot.plot_model_weights(model, figsize=(20,30), max_cols=8)
# Out:
# (21, 3, 8) --> (8, 3, 21)
# (8, 36, 8, 11) --> (88, 8, 36)
