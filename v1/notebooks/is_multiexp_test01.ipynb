# %%
import sys
# not best practice, but makes it easier to import from subdirectory
sys.path.insert(0, './lib')

import experiment as exp
import plot
# Out:
# Invoking __init__.py for NDNT.utils

# %%
e = exp.load('is_multiexp_test01', 'experiments')

# %%
e.trials
# Out:
#    null_adjusted_LL num_filters  num_inh_percent                         expt  \
# 0              True     32,16,8             0.75                expt04+expt05
# 0              True     32,16,8             0.75         expt04+expt05+expt06
# 0              True     32,16,8             0.75  expt04+expt05+expt06+expt07
# 0              True     32,16,8             0.75                expt04+expt05
# 0              True     32,16,8             0.75         expt04+expt05+expt06
# 0              True     32,16,8             0.75  expt04+expt05+expt06+expt07
#
#   kernel_widths kernel_heights  copy_weights  freeze_weights  include_MUs  \
# 0      21,21,21          3,3,3         False           False        False
# 0      21,21,21          3,3,3         False           False        False
# 0      21,21,21          3,3,3         False           False        False
# 0      21,21,21          3,3,3         False           False        False
# ...

# %%
e.plot_losses(trials=e.trials_where(is_multiexp=True))
# Out:
# lazy loading losses
# lazy loading losses
# lazy loading losses

# %%
e.plot_losses(trials=e.trials_where(is_multiexp=False))
# Out:
# lazy loading losses
# lazy loading losses
# lazy loading losses

# %%
e2 = exp.load('is_multiexp_test02', 'experiments')
e2.trials
# Out:
#    null_adjusted_LL num_filters  num_inh_percent                         expt  \
# 0              True     32,16,8             0.75                expt04+expt05
# 0              True     32,16,8             0.75         expt04+expt05+expt06
# 0              True     32,16,8             0.75  expt04+expt05+expt06+expt07
# 0              True     32,16,8             0.75                expt04+expt05
# 0              True     32,16,8             0.75         expt04+expt05+expt06
# 0              True     32,16,8             0.75  expt04+expt05+expt06+expt07
#
#   kernel_widths kernel_heights  copy_weights  freeze_weights  include_MUs  \
# 0      21,21,21          3,3,3         False           False        False
# 0      21,21,21          3,3,3         False           False        False
# 0      21,21,21          3,3,3         False           False        False
# 0      21,21,21          3,3,3         False           False        False
# ...

# %%
# plot predictions
model = e2.trials_where(name='cnim_scaffold2')[0].model
plot.plot_network_weights(model.networks[0], wspace=0.1, hspace=0.5, max_cols=16, figsize=(20,15))
# Out:
# (21, 10, 32) --> (32, 10, 21)
# (32, 21, 16) --> (16, 21, 32)
# (16, 21, 8) --> (8, 21, 16)

# %%
# plot predictions
model = e2.trials_where(name='cnim_scaffold5')[0].model
plot.plot_network_weights(model.networks[0], wspace=0.1, hspace=0.5, max_cols=16, figsize=(20,15))
# Out:
# (21, 10, 32) --> (32, 10, 21)
# (32, 21, 16) --> (16, 21, 32)
# (16, 21, 8) --> (8, 21, 16)

# %%
e3 = exp.load('is_multiexp_test04-2', 'experiments')
e3.trials
# Out:
#    null_adjusted_LL num_filters  num_inh_percent                         expt  \
# 0              True    24,20,16              0.5                expt04+expt05
# 0              True    24,20,16              0.5         expt04+expt05+expt06
# 0              True    24,20,16              0.5  expt04+expt05+expt06+expt07
# 0              True    24,20,16              0.5                expt04+expt05
# 0              True    24,20,16              0.5         expt04+expt05+expt06
# 0              True    24,20,16              0.5  expt04+expt05+expt06+expt07
#
#   kernel_widths kernel_heights  copy_weights  freeze_weights  include_MUs  \
# 0      21,21,21          3,3,3         False           False        False
# 0      21,21,21          3,3,3         False           False        False
# 0      21,21,21          3,3,3         False           False        False
# 0      21,21,21          3,3,3         False           False        False
# ...

# %%
# plot predictions
model = e3.trials_where(name='cnim_scaffold2')[0].model
plot.plot_network_weights(model.networks[0], wspace=0.1, hspace=0.5, max_cols=16, figsize=(20,15))
# Out:
# (21, 10, 24) --> (24, 10, 21)
# (24, 21, 20) --> (20, 21, 24)
# (20, 21, 16) --> (16, 21, 20)

# %%
# plot predictions
model = e3.trials_where(name='cnim_scaffold5')[0].model
plot.plot_network_weights(model.networks[0], wspace=0.1, hspace=0.5, max_cols=16, figsize=(20,15))
# Out:
# (21, 10, 24) --> (24, 10, 21)
# (24, 21, 20) --> (20, 21, 24)
# (20, 21, 16) --> (16, 21, 20)

# %%
e5 = exp.load('is_multiexp_test05', 'experiments')
e5.trials
# Out:
#    null_adjusted_LL num_filters  num_inh_percent  \
# 0              True    24,20,16             0.50
# 0              True    24,20,16             0.50
# 0              True    24,20,16             0.75
# 0              True    24,20,16             0.75
# 0              True    24,20,16             0.75
# 0              True    24,20,16             0.75
# 0              True    24,20,16             0.75
# 0              True    24,20,16             0.75
# 0              True    24,20,16             0.50
# 0              True    24,20,16             0.50
# 0              True    24,20,16             0.50
# 0              True    24,20,16             0.50
# 0              True    24,20,16             0.50
# 0              True    24,20,16             0.50
# 0              True    24,20,16             0.75
# 0              True    24,20,16             0.75
#
#                                  expt kernel_widths kernel_heights  \
# ...

# %%
# plot predictions
model = e3.trials_where(name='cnim_scaffold15')[0].model
plot.plot_network_weights(model.networks[0], wspace=0.1, hspace=0.5, max_cols=16, figsize=(20,15))
# Out:
# (21, 10, 24) --> (24, 10, 21)
# (24, 11, 20) --> (20, 11, 24)
# (20, 5, 16) --> (16, 5, 20)
