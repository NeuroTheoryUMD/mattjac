# %%
import sys
# not best practice, but makes it easier to import from subdirectory
sys.path.insert(0, './lib')

import experiment as exp
import plot

# %%
e = exp.load('is_multiexp_test01', 'experiments')

# %%
e.trials
# Out:
#    null_adjusted_LL num_filters  num_inh_percent                         expt  \
# 0              True     32,16,8             0.75                expt04+expt05
# 0              True     32,16,8             0.75         expt04+expt05+expt06
# 0              True     32,16,8             0.75  expt04+expt05+expt06+expt07
# 0              True     32,16,8             0.75                expt04+expt05
# 0              True     32,16,8             0.75         expt04+expt05+expt06
# 0              True     32,16,8             0.75  expt04+expt05+expt06+expt07
#
#   kernel_widths kernel_heights  copy_weights  freeze_weights  include_MUs  \
# 0      21,21,21          3,3,3         False           False        False
# 0      21,21,21          3,3,3         False           False        False
# 0      21,21,21          3,3,3         False           False        False
# 0      21,21,21          3,3,3         False           False        False
# 0      21,21,21          3,3,3         False           False        False
# 0      21,21,21          3,3,3         False           False        False
#
#    is_multiexp       modelstr  d2xt      l1  center          bcs  \
# 0         True  cnim_scaffold  0.01  0.0001    0.01  {'d2xt': 1}
# 0         True  cnim_scaffold  0.01  0.0001    0.01  {'d2xt': 1}
# 0         True  cnim_scaffold  0.01  0.0001    0.01  {'d2xt': 1}
# 0        False  cnim_scaffold  0.01  0.0001    0.01  {'d2xt': 1}
# 0        False  cnim_scaffold  0.01  0.0001    0.01  {'d2xt': 1}
# 0        False  cnim_scaffold  0.01  0.0001    0.01  {'d2xt': 1}
#
#              name                                        trial  mean_LLs
# 0  cnim_scaffold0  <experiment.Trial object at 0x7fd5a4227850>       inf
# 0  cnim_scaffold1  <experiment.Trial object at 0x7fd5a41b9a00>       inf
# 0  cnim_scaffold2  <experiment.Trial object at 0x7fd5a42675e0>       inf
# 0  cnim_scaffold3  <experiment.Trial object at 0x7fd5a422cf40>       inf
# 0  cnim_scaffold4  <experiment.Trial object at 0x7fd5a41b0460>       inf
# 0  cnim_scaffold5  <experiment.Trial object at 0x7fd5a428c6a0>       inf

# %%
e.plot_losses(trials=e.trials_where(is_multiexp=True))

# %%
e.plot_losses(trials=e.trials_where(is_multiexp=False))

# %%
e2 = exp.load('is_multiexp_test02', 'experiments')
e2.trials
# Out:
#    null_adjusted_LL num_filters  num_inh_percent                         expt  \
# 0              True     32,16,8             0.75                expt04+expt05
# 0              True     32,16,8             0.75         expt04+expt05+expt06
# 0              True     32,16,8             0.75  expt04+expt05+expt06+expt07
# 0              True     32,16,8             0.75                expt04+expt05
# 0              True     32,16,8             0.75         expt04+expt05+expt06
# 0              True     32,16,8             0.75  expt04+expt05+expt06+expt07
#
#   kernel_widths kernel_heights  copy_weights  freeze_weights  include_MUs  \
# 0      21,21,21          3,3,3         False           False        False
# 0      21,21,21          3,3,3         False           False        False
# 0      21,21,21          3,3,3         False           False        False
# 0      21,21,21          3,3,3         False           False        False
# 0      21,21,21          3,3,3         False           False        False
# 0      21,21,21          3,3,3         False           False        False
#
#    is_multiexp       modelstr  d2xt      l1  center          bcs  \
# 0         True  cnim_scaffold  0.01  0.0001    0.01  {'d2xt': 1}
# 0         True  cnim_scaffold  0.01  0.0001    0.01  {'d2xt': 1}
# 0         True  cnim_scaffold  0.01  0.0001    0.01  {'d2xt': 1}
# 0        False  cnim_scaffold  0.01  0.0001    0.01  {'d2xt': 1}
# 0        False  cnim_scaffold  0.01  0.0001    0.01  {'d2xt': 1}
# 0        False  cnim_scaffold  0.01  0.0001    0.01  {'d2xt': 1}
#
#              name                                        trial  mean_LLs
# 0  cnim_scaffold0  <experiment.Trial object at 0x7fd57bf1a910>  0.349163
# 0  cnim_scaffold1  <experiment.Trial object at 0x7fd57bece6a0>  0.290638
# 0  cnim_scaffold2  <experiment.Trial object at 0x7fd5a423f370>  0.285043
# 0  cnim_scaffold3  <experiment.Trial object at 0x7fd5a4267a30> -0.002568
# 0  cnim_scaffold4  <experiment.Trial object at 0x7fd57be79460> -0.002064
# 0  cnim_scaffold5  <experiment.Trial object at 0x7fd5a425d340> -0.001108

# %%
# plot predictions
model = e2.trials_where(name='cnim_scaffold2')[0].model
plot.plot_network_weights(model.networks[0], wspace=0.1, hspace=0.5, max_cols=16, figsize=(20,15))
# Out:
# (21, 10, 32) --> (32, 10, 21)
# (32, 21, 16) --> (16, 21, 32)
# (16, 21, 8) --> (8, 21, 16)

# %%
# plot predictions
model = e2.trials_where(name='cnim_scaffold5')[0].model
plot.plot_network_weights(model.networks[0], wspace=0.1, hspace=0.5, max_cols=16, figsize=(20,15))
# Out:
# (21, 10, 32) --> (32, 10, 21)
# (32, 21, 16) --> (16, 21, 32)
# (16, 21, 8) --> (8, 21, 16)
