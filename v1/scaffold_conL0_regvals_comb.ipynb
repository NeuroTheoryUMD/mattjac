# %%
import experiment as exp
import numpy as np
import matplotlib.pyplot as plt

# %%
e = exp.load('scaffold_conL0_regvals_comb')

# %%
e.plot_LLs()

# %%
e[0].model.networks[0].get_weights()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 e[0].model.networks[0].get_weights()
#
# AttributeError: 'Network' object has no attribute 'get_weights'
