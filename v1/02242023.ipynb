# %%
import sys
# not best practice, but makes it easier to import from subdirectory
sys.path.insert(0, './lib')
sys.path.insert(0, './archive')

import experiment as exp
import plot

# %load_ext autoreload
# %autoreload 2

plot.lightmode()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # num_inh & filters

# %%
e1 = exp.load('cnim_scaffold_3_layer', experiment_location='experiments', datadir='Mdata')
e1.trials
# Out:
#   num_filters  num_inh_percent                         expt kernel_widths  \
# 0    16,16,16             0.25                expt04+expt05      21,21,21
# 0    16,16,16             0.25         expt04+expt05+expt06      21,21,21
# 0    24,20,16             0.25         expt04+expt05+expt06      21,21,21
# 0    24,20,16             0.25  expt04+expt05+expt06+expt07      21,21,21
# 0    24,20,16             0.50                expt04+expt05      21,21,21
# 0    24,20,16             0.50         expt04+expt05+expt06      21,21,21
# 0    24,20,16             0.50  expt04+expt05+expt06+expt07      21,21,21
# 0    24,20,16             0.75                expt04+expt05      21,21,21
# 0    24,20,16             0.75         expt04+expt05+expt06      21,21,21
# 0    24,20,16             0.75  expt04+expt05+expt06+expt07      21,21,21
# 0    16,20,24             0.25                expt04+expt05      21,21,21
# 0    16,20,24             0.25         expt04+expt05+expt06      21,21,21
# 0    16,16,16             0.25  expt04+expt05+expt06+expt07      21,21,21
# 0    16,20,24             0.25  expt04+expt05+expt06+expt07      21,21,21
# 0    16,20,24             0.50                expt04+expt05      21,21,21
# 0    16,20,24             0.50         expt04+expt05+expt06      21,21,21
# 0    16,20,24             0.50  expt04+expt05+expt06+expt07      21,21,21
# 0    16,20,24             0.75                expt04+expt05      21,21,21
# 0    16,20,24             0.75         expt04+expt05+expt06      21,21,21
# 0    16,20,24             0.75  expt04+expt05+expt06+expt07      21,21,21
# 0    16,16,16             0.50                expt04+expt05      21,21,21
# 0    16,16,16             0.50         expt04+expt05+expt06      21,21,21
# 0    16,16,16             0.50  expt04+expt05+expt06+expt07      21,21,21
# 0    16,16,16             0.75                expt04+expt05      21,21,21
# 0    16,16,16             0.75         expt04+expt05+expt06      21,21,21
# 0    16,16,16             0.75  expt04+expt05+expt06+expt07      21,21,21
# 0    24,20,16             0.25                expt04+expt05      21,21,21
#
#   kernel_heights       modelstr  d2xt      l1  center          bcs  \
# 0          5,5,5  cnim_scaffold  0.01  0.0001    0.01  {'d2xt': 1}
# 0          5,5,5  cnim_scaffold  0.01  0.0001    0.01  {'d2xt': 1}
# 0          5,5,5  cnim_scaffold  0.01  0.0001    0.01  {'d2xt': 1}
# 0          5,5,5  cnim_scaffold  0.01  0.0001    0.01  {'d2xt': 1}
# 0          5,5,5  cnim_scaffold  0.01  0.0001    0.01  {'d2xt': 1}
# 0          5,5,5  cnim_scaffold  0.01  0.0001    0.01  {'d2xt': 1}
# 0          5,5,5  cnim_scaffold  0.01  0.0001    0.01  {'d2xt': 1}
# 0          5,5,5  cnim_scaffold  0.01  0.0001    0.01  {'d2xt': 1}
# 0          5,5,5  cnim_scaffold  0.01  0.0001    0.01  {'d2xt': 1}
# 0          5,5,5  cnim_scaffold  0.01  0.0001    0.01  {'d2xt': 1}
# 0          5,5,5  cnim_scaffold  0.01  0.0001    0.01  {'d2xt': 1}
# 0          5,5,5  cnim_scaffold  0.01  0.0001    0.01  {'d2xt': 1}
# 0          5,5,5  cnim_scaffold  0.01  0.0001    0.01  {'d2xt': 1}
# 0          5,5,5  cnim_scaffold  0.01  0.0001    0.01  {'d2xt': 1}
# 0          5,5,5  cnim_scaffold  0.01  0.0001    0.01  {'d2xt': 1}
# 0          5,5,5  cnim_scaffold  0.01  0.0001    0.01  {'d2xt': 1}
# 0          5,5,5  cnim_scaffold  0.01  0.0001    0.01  {'d2xt': 1}
# 0          5,5,5  cnim_scaffold  0.01  0.0001    0.01  {'d2xt': 1}
# 0          5,5,5  cnim_scaffold  0.01  0.0001    0.01  {'d2xt': 1}
# 0          5,5,5  cnim_scaffold  0.01  0.0001    0.01  {'d2xt': 1}
# 0          5,5,5  cnim_scaffold  0.01  0.0001    0.01  {'d2xt': 1}
# 0          5,5,5  cnim_scaffold  0.01  0.0001    0.01  {'d2xt': 1}
# 0          5,5,5  cnim_scaffold  0.01  0.0001    0.01  {'d2xt': 1}
# 0          5,5,5  cnim_scaffold  0.01  0.0001    0.01  {'d2xt': 1}
# 0          5,5,5  cnim_scaffold  0.01  0.0001    0.01  {'d2xt': 1}
# 0          5,5,5  cnim_scaffold  0.01  0.0001    0.01  {'d2xt': 1}
# 0          5,5,5  cnim_scaffold  0.01  0.0001    0.01  {'d2xt': 1}
#
#               name                                        trial  mean_LLs
# 0   cnim_scaffold0  <experiment.Trial object at 0x7f1e928c0430>  0.076183
# 0   cnim_scaffold1  <experiment.Trial object at 0x7f1db60b5700>  0.109383
# 0  cnim_scaffold10  <experiment.Trial object at 0x7f1e00a669d0>  0.116555
# 0  cnim_scaffold11  <experiment.Trial object at 0x7f1e00a66640>  0.039968
# 0  cnim_scaffold12  <experiment.Trial object at 0x7f1db62bbb80> -0.046753
# 0  cnim_scaffold13  <experiment.Trial object at 0x7f1e006eb460>  0.120415
# 0  cnim_scaffold14  <experiment.Trial object at 0x7f1db66af520> -0.018871
# 0  cnim_scaffold15  <experiment.Trial object at 0x7f1db4ac7130> -0.104326
# 0  cnim_scaffold16  <experiment.Trial object at 0x7f1db605fd30>  0.111432
# 0  cnim_scaffold17  <experiment.Trial object at 0x7f1db6683910> -0.104427
# 0  cnim_scaffold18  <experiment.Trial object at 0x7f1db4ffd580>  0.211289
# 0  cnim_scaffold19  <experiment.Trial object at 0x7f1e9267fbb0>  0.095633
# 0   cnim_scaffold2  <experiment.Trial object at 0x7f1e0070bd00> -0.040959
# 0  cnim_scaffold20  <experiment.Trial object at 0x7f1db605fa90> -0.057418
# 0  cnim_scaffold21  <experiment.Trial object at 0x7f1db6087910> -0.032373
# 0  cnim_scaffold22  <experiment.Trial object at 0x7f1db56df0d0>  0.118839
# 0  cnim_scaffold23  <experiment.Trial object at 0x7f1db6068d90> -0.088024
# 0  cnim_scaffold24  <experiment.Trial object at 0x7f1e00a8f160> -0.085078
# 0  cnim_scaffold25  <experiment.Trial object at 0x7f1db500dee0>  0.112787
# 0  cnim_scaffold26  <experiment.Trial object at 0x7f1db6685a60> -0.086044
# 0   cnim_scaffold3  <experiment.Trial object at 0x7f1db66b6af0> -0.050207
# 0   cnim_scaffold4  <experiment.Trial object at 0x7f1db6692130>  0.113816
# 0   cnim_scaffold5  <experiment.Trial object at 0x7f1db5cb1b80> -0.006008
# 0   cnim_scaffold6  <experiment.Trial object at 0x7f1db5038940> -0.135442
# 0   cnim_scaffold7  <experiment.Trial object at 0x7f1e00152a60>  0.102218
# 0   cnim_scaffold8  <experiment.Trial object at 0x7f1db56c7580> -0.037792
# 0   cnim_scaffold9  <experiment.Trial object at 0x7f1db5526730>  0.085640

# %%
# TODO: plot the inhibitory and excitatory filters, and try to make sense of them
plot.plot_model_weights(e1.trials_where(name='cnim_scaffold11')[0].model, cmap='inferno', figsize=(20,20))
# Out:
# (21, 10, 24) --> (24, 10, 21)
# (24, 21, 20) --> (20, 21, 24)
# (20, 21, 16) --> (16, 21, 20)
# (60, 36, 29) --> (29, 36, 60)

# %% [markdown]
# # copy weights

# %%
e2 = exp.load('cnim_scaffold_3_layer_v2', experiment_location='experiments', datadir='Mdata')
e2.trials
# Out:
#    null_adjusted_LL num_filters  num_inh_percent                  expt  \
# 0              True    24,20,16             0.75         expt04+expt05
# 0              True    24,20,16             0.75  expt04+expt05+expt06
# 0              True    24,20,16             0.75         expt04+expt05
# 0              True    24,20,16             0.75  expt04+expt05+expt06
#
#   kernel_widths  copy_weights       modelstr  d2xt      l1  center  \
# 0      21,21,21          True  cnim_scaffold  0.01  0.0001    0.01
# 0      21,21,21          True  cnim_scaffold  0.01  0.0001    0.01
# 0      21,21,21         False  cnim_scaffold  0.01  0.0001    0.01
# 0      21,21,21         False  cnim_scaffold  0.01  0.0001    0.01
#
#            bcs            name                                        trial  \
# 0  {'d2xt': 1}  cnim_scaffold0  <experiment.Trial object at 0x7f1db65d6e50>
# 0  {'d2xt': 1}  cnim_scaffold1  <experiment.Trial object at 0x7f1db65c41f0>
# 0  {'d2xt': 1}  cnim_scaffold2  <experiment.Trial object at 0x7f1e0068e730>
# 0  {'d2xt': 1}  cnim_scaffold3  <experiment.Trial object at 0x7f1e00691e80>
#
#    mean_LLs
# 0 -0.133848
# 0  0.119464
# 0 -0.119999
# 0  0.125117

# %%
plot.plot_model_weights(e2.trials_where(name='cnim_scaffold3')[0].model, cmap='Spectral', figsize=(20,20))
# Out:
# (21, 10, 24) --> (24, 10, 21)
# (24, 21, 20) --> (20, 21, 24)
# (20, 21, 16) --> (16, 21, 20)
# (60, 36, 25) --> (25, 36, 60)

# %%
e3 = exp.load('cnim_scaffold_3_layer_v3', experiment_location='experiments', datadir='Mdata')
e3.trials
# Out:
#    null_adjusted_LL num_filters  num_inh_percent                  expt  \
# 0              True    24,20,16             0.75         expt04+expt05
# 0              True    24,20,16             0.75  expt04+expt05+expt06
# 0              True    24,20,16             0.75         expt04+expt05
# 0              True    24,20,16             0.75  expt04+expt05+expt06
#
#   kernel_widths  copy_weights       modelstr  d2xt      l1  center  \
# 0      21,21,21          True  cnim_scaffold  0.01  0.0001    0.01
# 0      21,21,21          True  cnim_scaffold  0.01  0.0001    0.01
# 0      21,21,21         False  cnim_scaffold  0.01  0.0001    0.01
# 0      21,21,21         False  cnim_scaffold  0.01  0.0001    0.01
#
#            bcs            name                                        trial  \
# 0  {'d2xt': 1}  cnim_scaffold0  <experiment.Trial object at 0x7f1db65c45b0>
# 0  {'d2xt': 1}  cnim_scaffold1  <experiment.Trial object at 0x7f1db65d6a00>
# 0  {'d2xt': 1}  cnim_scaffold2  <experiment.Trial object at 0x7f1db6398be0>
# 0  {'d2xt': 1}  cnim_scaffold3  <experiment.Trial object at 0x7f1db65f7a90>
#
#    mean_LLs
# 0 -0.142775
# 0  0.088524
# 0 -0.145244
# 0  0.122336

# %%
plot.plot_model_weights(e3.trials_where(name='cnim_scaffold1')[0].model, cmap='gray', figsize=(20,20))
# Out:
# (21, 10, 24) --> (24, 10, 21)
# (24, 21, 20) --> (20, 21, 24)
# (20, 21, 16) --> (16, 21, 20)
# (60, 36, 25) --> (25, 36, 60)

# %% [markdown]
# # freeze weights

# %%
e4 = exp.load('cnim_scaffold_3_layer_v4', experiment_location='experiments', datadir='Mdata')
e4.trials
# Out:
#    null_adjusted_LL num_filters  num_inh_percent                  expt  \
# 0              True    24,20,16             0.75         expt04+expt05
# 0              True    24,20,16             0.75  expt04+expt05+expt06
# 0              True    24,20,16             0.75         expt04+expt05
# 0              True    24,20,16             0.75  expt04+expt05+expt06
#
#   kernel_widths  copy_weights  freeze_weights       modelstr  d2xt      l1  \
# 0      21,21,21          True            True  cnim_scaffold  0.01  0.0001
# 0      21,21,21          True            True  cnim_scaffold  0.01  0.0001
# 0      21,21,21          True           False  cnim_scaffold  0.01  0.0001
# 0      21,21,21          True           False  cnim_scaffold  0.01  0.0001
#
#    center          bcs            name  \
# 0    0.01  {'d2xt': 1}  cnim_scaffold0
# 0    0.01  {'d2xt': 1}  cnim_scaffold1
# 0    0.01  {'d2xt': 1}  cnim_scaffold2
# 0    0.01  {'d2xt': 1}  cnim_scaffold3
#
#                                          trial  mean_LLs
# 0  <experiment.Trial object at 0x7f1dafb37d90> -0.126397
# 0  <experiment.Trial object at 0x7f1dd4098760> -0.206143
# 0  <experiment.Trial object at 0x7f1db455c9a0> -0.141906
# 0  <experiment.Trial object at 0x7f1dae227040>  0.112333

# %% [markdown]
# # TODO: try multiunits

# %%
# just include_MUs in the dataset when it is created, I believe
e4 = exp.load('cnim_scaffold_3_layer_v4', experiment_location='experiments', datadir='Mdata')
e4.trials
# Out:
#    null_adjusted_LL num_filters  num_inh_percent                         expt  \
# 0              True    24,20,16             0.75                expt04+expt05
# 0              True    24,20,16             0.75         expt04+expt05+expt06
# 0              True    24,20,16             0.75         expt04+expt05+expt06
# 0              True    24,20,16             0.75  expt04+expt05+expt06+expt07
# 0              True    24,20,16             0.75                expt04+expt05
# 0              True    24,20,16             0.75         expt04+expt05+expt06
# 0              True    24,20,16             0.75  expt04+expt05+expt06+expt07
# 0              True    24,20,16             0.75                expt04+expt05
# 0              True    24,20,16             0.75         expt04+expt05+expt06
# 0              True    24,20,16             0.75  expt04+expt05+expt06+expt07
# 0              True    24,20,16             0.75                expt04+expt05
# 0              True    24,20,16             0.75         expt04+expt05+expt06
# 0              True    24,20,16             0.75  expt04+expt05+expt06+expt07
# 0              True    24,20,16             0.75  expt04+expt05+expt06+expt07
# 0              True    24,20,16             0.75                expt04+expt05
# 0              True    24,20,16             0.75         expt04+expt05+expt06
# 0              True    24,20,16             0.75  expt04+expt05+expt06+expt07
# 0              True    24,20,16             0.50                expt04+expt05
# 0              True    24,20,16             0.75                expt04+expt05
# 0              True    24,20,16             0.75         expt04+expt05+expt06
# 0              True    24,20,16             0.75  expt04+expt05+expt06+expt07
# 0              True    24,20,16             0.75                expt04+expt05
# 0              True    24,20,16             0.75         expt04+expt05+expt06
# 0              True    24,20,16             0.75  expt04+expt05+expt06+expt07
# 0              True    24,20,16             0.75                expt04+expt05
#
#   kernel_widths  copy_weights  freeze_weights  include_MUs       modelstr  \
# 0      21,21,21         False           False         True  cnim_scaffold
# 0      21,21,21         False           False         True  cnim_scaffold
# 0      21,21,21          True           False        False  cnim_scaffold
# 0      21,21,21          True           False        False  cnim_scaffold
# 0      15,15,15         False           False         True  cnim_scaffold
# 0      15,15,15         False           False         True  cnim_scaffold
# 0      15,15,15         False           False         True  cnim_scaffold
# 0      15,15,15         False           False        False  cnim_scaffold
# 0      15,15,15         False           False        False  cnim_scaffold
# 0      15,15,15         False           False        False  cnim_scaffold
# 0      15,15,15          True           False         True  cnim_scaffold
# 0      15,15,15          True           False         True  cnim_scaffold
# 0      21,21,21         False           False         True  cnim_scaffold
# 0      15,15,15          True           False         True  cnim_scaffold
# 0      15,15,15          True           False        False  cnim_scaffold
# 0      15,15,15          True           False        False  cnim_scaffold
# 0      15,15,15          True           False        False  cnim_scaffold
# 0      21,21,21         False           False         True  cnim_scaffold
# 0      21,21,21         False           False        False  cnim_scaffold
# 0      21,21,21         False           False        False  cnim_scaffold
# 0      21,21,21         False           False        False  cnim_scaffold
# 0      21,21,21          True           False         True  cnim_scaffold
# 0      21,21,21          True           False         True  cnim_scaffold
# 0      21,21,21          True           False         True  cnim_scaffold
# 0      21,21,21          True           False        False  cnim_scaffold
#
#    d2xt      l1  center          bcs             name  \
# 0  0.01  0.0001    0.01  {'d2xt': 1}   cnim_scaffold0
# 0  0.01  0.0001    0.01  {'d2xt': 1}   cnim_scaffold1
# 0  0.01  0.0001    0.01  {'d2xt': 1}  cnim_scaffold10
# 0  0.01  0.0001    0.01  {'d2xt': 1}  cnim_scaffold11
# 0  0.01  0.0001    0.01  {'d2xt': 1}  cnim_scaffold12
# 0  0.01  0.0001    0.01  {'d2xt': 1}  cnim_scaffold13
# 0  0.01  0.0001    0.01  {'d2xt': 1}  cnim_scaffold14
# 0  0.01  0.0001    0.01  {'d2xt': 1}  cnim_scaffold15
# 0  0.01  0.0001    0.01  {'d2xt': 1}  cnim_scaffold16
# 0  0.01  0.0001    0.01  {'d2xt': 1}  cnim_scaffold17
# 0  0.01  0.0001    0.01  {'d2xt': 1}  cnim_scaffold18
# 0  0.01  0.0001    0.01  {'d2xt': 1}  cnim_scaffold19
# 0  0.01  0.0001    0.01  {'d2xt': 1}   cnim_scaffold2
# 0  0.01  0.0001    0.01  {'d2xt': 1}  cnim_scaffold20
# 0  0.01  0.0001    0.01  {'d2xt': 1}  cnim_scaffold21
# 0  0.01  0.0001    0.01  {'d2xt': 1}  cnim_scaffold22
# 0  0.01  0.0001    0.01  {'d2xt': 1}  cnim_scaffold23
# 0  0.01  0.0001    0.01  {'d2xt': 1}  cnim_scaffold24
# 0  0.01  0.0001    0.01  {'d2xt': 1}   cnim_scaffold3
# 0  0.01  0.0001    0.01  {'d2xt': 1}   cnim_scaffold4
# 0  0.01  0.0001    0.01  {'d2xt': 1}   cnim_scaffold5
# 0  0.01  0.0001    0.01  {'d2xt': 1}   cnim_scaffold6
# 0  0.01  0.0001    0.01  {'d2xt': 1}   cnim_scaffold7
# 0  0.01  0.0001    0.01  {'d2xt': 1}   cnim_scaffold8
# 0  0.01  0.0001    0.01  {'d2xt': 1}   cnim_scaffold9
#
#                                          trial  mean_LLs
# 0  <experiment.Trial object at 0x7f1e00280c40>  0.084689
# 0  <experiment.Trial object at 0x7f1db59688b0>  0.022913
# 0  <experiment.Trial object at 0x7f1db46dedf0>  0.115473
# 0  <experiment.Trial object at 0x7f1e001fdd90> -0.016972
# 0  <experiment.Trial object at 0x7f1dae0a1a30>  0.084876
# 0  <experiment.Trial object at 0x7f1db5f0dd30>  0.017091
# 0  <experiment.Trial object at 0x7f1db5cf3220> -0.020083
# 0  <experiment.Trial object at 0x7f1db4913f10> -0.144441
# 0  <experiment.Trial object at 0x7f1db6611940>  0.104418
# 0  <experiment.Trial object at 0x7f1e0098d3d0> -0.172910
# 0  <experiment.Trial object at 0x7f1dade12130> -0.008548
# 0  <experiment.Trial object at 0x7f1dae2bf970>  0.019571
# 0  <experiment.Trial object at 0x7f1db4501cd0> -0.010529
# 0  <experiment.Trial object at 0x7f1db6611370> -0.033879
# 0  <experiment.Trial object at 0x7f1dae2a5ac0> -0.095106
# 0  <experiment.Trial object at 0x7f1dae2a1f70>  0.114303
# 0  <experiment.Trial object at 0x7f1db54a8eb0> -0.055957
# 0  <experiment.Trial object at 0x7f1e000fbbb0>  0.077990
# 0  <experiment.Trial object at 0x7f1e001fd4f0> -0.168879
# 0  <experiment.Trial object at 0x7f1e008248b0>  0.114394
# 0  <experiment.Trial object at 0x7f1db58bbfa0> -0.093227
# 0  <experiment.Trial object at 0x7f1db4676280>  0.073952
# 0  <experiment.Trial object at 0x7f1db5f0ddc0>  0.019063
# 0  <experiment.Trial object at 0x7f1db5cc2cd0> -0.005926
# 0  <experiment.Trial object at 0x7f1db46e1730> -0.163351

# %%
trial = e4.trials_where(name='cnim_scaffold0')[0]

# %% [markdown]
# # look at eval on the MUs using the SUs only

# %%
# just include_MUs in the dataset when it is created, I believe
e5 = exp.load('cnim_scaffold_3_layer_v5', experiment_location='experiments', datadir='Mdata')
e5.trials
# Out:
#    null_adjusted_LL num_filters  num_inh_percent                         expt  \
# 0              True    32,40,48             0.75                expt04+expt05
# 0              True    32,40,48             0.75         expt04+expt05+expt06
# 0              True    48,40,32             0.50         expt04+expt05+expt06
# 0              True    48,40,32             0.50  expt04+expt05+expt06+expt07
# 0              True    32,40,48             0.75  expt04+expt05+expt06+expt07
# 0              True    32,40,48             0.50                expt04+expt05
# 0              True    32,40,48             0.50         expt04+expt05+expt06
# 0              True    32,40,48             0.50  expt04+expt05+expt06+expt07
# 0              True    48,40,32             0.75                expt04+expt05
# 0              True    48,40,32             0.75         expt04+expt05+expt06
# 0              True    48,40,32             0.75  expt04+expt05+expt06+expt07
# 0              True    48,40,32             0.50                expt04+expt05
#
#   kernel_widths kernel_heights  copy_weights  freeze_weights  include_MUs  \
# 0      21,21,21          3,3,3         False           False         True
# 0      21,21,21          3,3,3         False           False         True
# 0      21,21,21          3,3,3         False           False         True
# 0      21,21,21          3,3,3         False           False         True
# 0      21,21,21          3,3,3         False           False         True
# 0      21,21,21          3,3,3         False           False         True
# 0      21,21,21          3,3,3         False           False         True
# 0      21,21,21          3,3,3         False           False         True
# 0      21,21,21          3,3,3         False           False         True
# 0      21,21,21          3,3,3         False           False         True
# 0      21,21,21          3,3,3         False           False         True
# 0      21,21,21          3,3,3         False           False         True
#
#         modelstr  d2xt      l1  center          bcs             name  \
# 0  cnim_scaffold  0.01  0.0001    0.01  {'d2xt': 1}   cnim_scaffold0
# 0  cnim_scaffold  0.01  0.0001    0.01  {'d2xt': 1}   cnim_scaffold1
# 0  cnim_scaffold  0.01  0.0001    0.01  {'d2xt': 1}  cnim_scaffold10
# 0  cnim_scaffold  0.01  0.0001    0.01  {'d2xt': 1}  cnim_scaffold11
# 0  cnim_scaffold  0.01  0.0001    0.01  {'d2xt': 1}   cnim_scaffold2
# 0  cnim_scaffold  0.01  0.0001    0.01  {'d2xt': 1}   cnim_scaffold3
# 0  cnim_scaffold  0.01  0.0001    0.01  {'d2xt': 1}   cnim_scaffold4
# 0  cnim_scaffold  0.01  0.0001    0.01  {'d2xt': 1}   cnim_scaffold5
# 0  cnim_scaffold  0.01  0.0001    0.01  {'d2xt': 1}   cnim_scaffold6
# 0  cnim_scaffold  0.01  0.0001    0.01  {'d2xt': 1}   cnim_scaffold7
# 0  cnim_scaffold  0.01  0.0001    0.01  {'d2xt': 1}   cnim_scaffold8
# 0  cnim_scaffold  0.01  0.0001    0.01  {'d2xt': 1}   cnim_scaffold9
#
#                                          trial  mean_LLs
# 0  <experiment.Trial object at 0x7f1dadfe7d60>       inf
# 0  <experiment.Trial object at 0x7f1dec0f7d00>       inf
# 0  <experiment.Trial object at 0x7f1e00637130>       inf
# 0  <experiment.Trial object at 0x7f1db5e6e670>       inf
# 0  <experiment.Trial object at 0x7f1db444c040>       inf
# 0  <experiment.Trial object at 0x7f1db6272a60>       inf
# 0  <experiment.Trial object at 0x7f1e006377c0>       inf
# 0  <experiment.Trial object at 0x7f1db4a74c70>       inf
# 0  <experiment.Trial object at 0x7f1db59ff700>       inf
# 0  <experiment.Trial object at 0x7f1db5f67820>       inf
# 0  <experiment.Trial object at 0x7f1dadfedbb0>       inf
# 0  <experiment.Trial object at 0x7f1dadf01be0>       inf

# %%
import matplotlib.pyplot as plt
trial = e5.trials_where(name='cnim_scaffold0')[0]
plt.plot(trial.LLs)

# set_cells, only subselect the units that are not inf
# look at eval_models
# make sure the MUs all have firing rates
