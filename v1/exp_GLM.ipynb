# %%
import experiment as exp
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import mattplotlib as mplt
import seaborn as sns
# Out:
# Invoking __init__.py for NDNT.utils

# %%
e = exp.load('simple_glm_test', 'experiments')

# %%
e['GLM_expt04'].model.get_network('GLM').layers[0].get_weights()
# Out:
# array([[[-8.25984807e-06, -4.46747026e-06, -7.07291201e-06, ...,
#          -2.44312696e-06, -5.86881788e-06, -1.00374782e-05],
#         [-3.34578908e-05, -6.69994115e-05,  6.53111128e-05, ...,
#           5.79969537e-06,  4.54572182e-05, -3.47937603e-05],
#         [ 1.12037320e-04, -2.23149647e-04,  4.45012920e-05, ...,
#           1.28102256e-04, -2.04267417e-06,  1.26809246e-04],
#         ...,
#         [ 3.63754341e-04, -3.41749546e-04, -6.74944022e-04, ...,
#           1.84315111e-04,  3.06873517e-05, -6.47347362e-04],
#         [ 1.05268358e-04,  1.91382424e-04, -7.72868952e-05, ...,
#          -1.76850808e-04,  2.13829699e-04, -1.83833999e-05],
#         [ 1.50210644e-05,  7.60446201e-05,  4.78034090e-05, ...,
#           6.39082864e-05, -5.77951250e-05,  1.98842590e-05]],
#
#        [[ 1.12816106e-05,  1.56983224e-05,  1.75968216e-05, ...,
#           5.07765071e-06, -9.66047537e-06, -6.44698821e-06],
#         [ 9.86395535e-05, -9.87999665e-05, -5.20352341e-06, ...,
#          -8.45937684e-05, -4.53757057e-05,  8.72414894e-05],
#         [-3.62503604e-04,  4.45505837e-04, -4.49887273e-04, ...,
#          -2.06724944e-04, -1.81460113e-04, -1.30605375e-04],
#         ...,
#         [ 6.40589496e-05, -6.66111882e-05, -2.76993844e-04, ...,
#          -8.42694833e-04,  7.84706441e-04, -9.95824579e-04],
#         [-3.19802057e-04, -3.64642561e-04,  2.28290766e-04, ...,
#          -1.65666788e-04,  7.35271556e-07, -3.18469713e-04],
#         [ 8.04571027e-05,  7.56978479e-05, -9.55644100e-06, ...,
#          -3.58229699e-05, -6.51224691e-05, -9.05082052e-05]],
#
#        [[-3.35368495e-05, -1.79399976e-05, -2.45689771e-05, ...,
#          -3.25796900e-05, -1.97644858e-05, -1.89821512e-05],
#         [ 1.99714108e-04,  3.36196208e-05, -4.16779621e-05, ...,
#          -9.05997967e-06, -8.88293071e-05,  7.57941962e-05],
#         [-1.47916562e-05,  4.02607489e-04, -5.16926637e-04, ...,
#          -5.52681508e-04, -5.63738577e-04,  1.12624395e-04],
#         ...,
#         [ 1.25069462e-03,  1.54966465e-03,  6.62033621e-04, ...,
#          -4.32234025e-04, -5.77367318e-04,  4.01832513e-04],
#         [ 3.11290438e-04, -5.54087746e-04, -1.22862097e-04, ...,
#          -5.93680830e-04,  5.15093212e-04, -4.20180295e-04],
#         [-4.82836513e-05,  5.50095228e-06, -1.14955124e-04, ...,
#           1.76414513e-04, -3.27215857e-05, -1.90734005e-04]],
#
#        ...,
#
#        [[-4.55788213e-05, -1.66860791e-05, -4.65739395e-05, ...,
#           4.89124614e-05,  3.20300387e-05,  2.31120202e-06],
#         [ 3.02122528e-04,  1.14988310e-04,  2.25214215e-04, ...,
#           1.53267611e-04,  7.55759611e-05,  4.80902199e-05],
#         [-1.08852773e-03,  1.10596455e-04, -2.79440195e-04, ...,
#           1.42940917e-04, -3.46153305e-04, -7.83729600e-04],
#         ...,
#         [-1.74548826e-03, -1.54423318e-03,  1.85080420e-03, ...,
#           9.50161557e-05, -2.47189007e-03,  2.31894082e-03],
#         [-3.09627612e-05, -8.50444427e-04,  1.75772191e-04, ...,
#          -1.31084758e-04, -1.04119099e-04, -4.96001332e-04],
#         [ 2.15765976e-04, -1.03850522e-04, -1.38322037e-04, ...,
#          -1.54107940e-04,  2.03727002e-04, -1.90725914e-04]],
#
#        [[-6.01571173e-06, -2.64483133e-05,  2.92484092e-05, ...,
#          -1.27826834e-05, -5.50533105e-06, -8.52583162e-06],
#         [-1.95918637e-05, -5.77766477e-05,  1.48016086e-04, ...,
#          -1.79788301e-04, -4.44069956e-05, -9.09282244e-05],
#         [ 5.50493423e-04, -5.45660674e-04,  6.86370477e-04, ...,
#          -5.02384792e-04,  3.57479672e-04,  2.39513392e-04],
#         ...,
#         [-7.69799808e-04, -6.39137463e-04,  6.97829411e-04, ...,
#          -1.02504448e-03,  1.74135529e-03,  1.44460786e-03],
#         [ 1.53921254e-04,  6.84395956e-04,  1.99725211e-04, ...,
#           7.09293294e-04,  7.08723848e-04,  2.96830840e-04],
#         [-1.75599736e-04,  1.57986160e-05, -9.70968540e-05, ...,
#          -1.41097378e-04,  1.91730396e-05,  1.01299935e-04]],
#
#        [[ 1.76553258e-05, -1.20605023e-06, -8.91577031e-07, ...,
#           1.02244376e-05,  1.63346976e-05,  1.90473438e-05],
#         [ 1.24688795e-05,  6.91022578e-05, -5.69975891e-05, ...,
#           6.27324989e-05,  1.17392148e-04, -6.50737566e-05],
#         [-1.68848001e-05, -3.74202995e-04,  3.02311208e-04, ...,
#          -2.44755414e-04,  1.46347171e-04,  2.22204020e-04],
#         ...,
#         [-1.07132061e-03, -5.17610344e-04,  6.11961645e-04, ...,
#           3.04055393e-05, -4.38176939e-04, -6.07851136e-04],
#         [-1.00298232e-04,  2.26449221e-04, -4.35327849e-04, ...,
#           3.49062204e-04, -3.76967582e-05, -9.93505273e-06],
#         [ 5.25322939e-05,  3.94446579e-05, -1.17398609e-04, ...,
#           4.19079042e-05, -1.22218436e-04,  1.21002799e-04]]],
#       dtype=float32)

# %%
mplt.lightmode()
e.plotLLs()

# %%
e['m0d0f0'].model.NDN.list_parameters()

# %%
e['m1d0f0'].model.NDN.list_parameters()

# %%
e['m0d0f0'].model.NDN.list_parameters()

# %%
e[0].model.get_network('readout').layers[-1].get_weights()

# %%
mplt.darkmode()
plt.figure(figsize=(15,5))
for trial in e.trials:
    if 'm1' in trial.name: continue
    plt.scatter(range(len(trial.LLs)), trial.LLs, label=trial.name, marker='s')
plt.legend()
plt.show()

# %%
mplt.lightmode()

df = pd.DataFrame({
    'Factor': ['Growth', 'Value'],
    'Weight': [0.10, 0.20],
    'Variance': [0.15, 0.35]
})
fig, ax1 = plt.subplots(figsize=(10, 5))
tidy = df.melt(id_vars='Factor').rename(columns=str.title)
sns.barplot(x='Factor', y='Value', hue='Variable', data=tidy, ax=ax1)
sns.despine(fig)

# %%
# get maximum num_neurons for the experiment
max_num_neurons = 0
for trial in e.trials:
    if trial.model.output.num_neurons > max_num_neurons:
        max_num_neurons = trial.model.output.num_neurons

df = pd.DataFrame({
    'Neuron': ['N'+str(n) for n in range(max_num_neurons)],
})
for trial in e.trials:
    df[trial.name] = np.concatenate((trial.LLs, np.zeros(max_num_neurons-len(trial.LLs), dtype=np.float32)))
fig, ax1 = plt.subplots(figsize=(20, 5))
tidy = df.melt(id_vars='Neuron').rename(columns=str.title)
sns.barplot(x='Neuron', y='Value', hue='Variable', data=tidy, ax=ax1)
sns.despine(fig)

# %%
trial.LLs, np.zeros(max_num_neurons-len(trial.LLs), dtype=np.float32)

# %%
from model import *
l0 = Layer(NLtype=NL.relu, norm_type=Norm.max)

# %%
mplt.lightmode()
e.model_template.draw_network()
