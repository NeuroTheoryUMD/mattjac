# %%
import experiment as exp
# Out:
# Invoking __init__.py for NDNT.utils

# %%
e = exp.load('exp_CNIM_copyweights', 'experiments')

# %%
e.trials[(e.trials.num_filters==16) & (e.trials.expt != 'expt04')]
# Out:
#    copy_weights  num_filters                         expt    name  \
# 0          True           16                expt04+expt05  CNIM17
# 0          True           16         expt04+expt05+expt06  CNIM18
# 0          True           16  expt04+expt05+expt06+expt07  CNIM19
# 0         False           16                expt04+expt05  CNIM21
# 0         False           16         expt04+expt05+expt06  CNIM22
# 0         False           16  expt04+expt05+expt06+expt07  CNIM23
#
#                                          trial  mean_LLs
# 0  <experiment.Trial object at 0x7f7370db0160>  0.180159
# 0  <experiment.Trial object at 0x7f7368392d60>  0.074103
# 0  <experiment.Trial object at 0x7f73684b4dc0>  0.076972
# 0  <experiment.Trial object at 0x7f73683c53d0>  0.130876
# 0  <experiment.Trial object at 0x7f736841a280>  0.080151
# 0  <experiment.Trial object at 0x7f73685020d0>  0.068692

# %%
e.plot_LLs(trials=e.trials_where(num_filters=16, expt='expt04+expt05+expt06+expt07'))
