# %%
import experiment as exp
# Out:
# Invoking __init__.py for NDNT.utils

# %%
e = exp.load('expSCAF', 'experiments')

# %%
e.trials_where(name='SCAF_NF4_expt04')[0].model.draw_network()

# %%
e.trials
# Out:
#    num_filters                         expt  \
# 0            4                       expt04
# 0            4                expt04+expt05
# 0            4         expt04+expt05+expt06
# 0            4  expt04+expt05+expt06+expt07
# 0            6                       expt04
# 0            6                expt04+expt05
# 0            6         expt04+expt05+expt06
# 0            6  expt04+expt05+expt06+expt07
# 0            8                       expt04
# 0            8                expt04+expt05
# 0            8         expt04+expt05+expt06
# 0            8  expt04+expt05+expt06+expt07
#
#                                    name  \
# 0                       SCAF_NF4_expt04
# 0                SCAF_NF4_expt04+expt05
# 0         SCAF_NF4_expt04+expt05+expt06
# 0  SCAF_NF4_expt04+expt05+expt06+expt07
# 0                       SCAF_NF6_expt04
# 0                SCAF_NF6_expt04+expt05
# 0         SCAF_NF6_expt04+expt05+expt06
# 0  SCAF_NF6_expt04+expt05+expt06+expt07
# ...

# %%
e.plot_LLs(trials=e.trials_where(num_filters=4))

# %%
e.plot_LLs(trials=e.trials_where(num_filters=6))

# %%
e.plot_LLs(trials=e.trials_where(num_filters=8))

# %%
e.plot_losses(trials=e.trials_where(num_filters=8))
# Out:
# lazy loading losses
# lazy loading losses
# lazy loading losses
# lazy loading losses
